# %% [markdown]
# # Read data
# There are different ways to read data with Python.

# %% [markdown]
# ### 1 The most popular way is to read a .csv file.
# To do so, the following function has to be called and the Pandas module has to be loaded. Then, add the location of the file.

# %%
import pandas as pd

testfile = pd.read_csv("C:/Users/tamta/Documents/Arbeit/04_StHk_KlimaAG_UniMarburg_2/04_Bearbeitung/07_Ökodaten/data/501_ClimateStationBOM_complete/501_ClimateStationBOM_complete.csv")
testfile.head()
# Out:
#    gRaddown gRaddown_quality  PCP PCP_quality  Huma_2m Huma_2m_quality  Ta_2m  \
# 0       0.0                a  0.0           a     86.9               m   24.5
# 1       0.0                a  0.0           a     94.7               m   22.3
# 2       0.0                a  0.0           a     97.7               m   20.6
# 3       0.0                a  0.0           a     98.8               m   19.7
# 4       0.0                a  0.0           a     99.2               m   19.0
#
#   Ta_2m_quality  Ts_10cm Ts_10cm_quality  Ts_60cm Ts_60cm_quality  \
# 0             a     24.8               a     23.5               a
# 1             a     25.1               a     23.5               a
# 2             a     25.2               a     23.4               a
# 3             a     25.2               a     23.4               a
# 4             a     25.1               a     23.4               a
#
#    Wind_direction Wind_direction_quality  Windspeed Windspeed_quality  gRad1  \
# ...
